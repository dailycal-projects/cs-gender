# %%
import numpy as np
import pandas as pd
names = ['year','','','','','gender','','','headcount','','','','dept','major']
df = pd.read_csv('degrees.csv',names=names,header=0,usecols=[0,5,8,12,13])

# %%
df.head()
# Out:
#       year            gender  headcount                      dept  \
# 0  1983-84  Decline to State          1  African American Studies
# 1  1983-84  Decline to State          1  African American Studies
# 2  1983-84  Decline to State          9  Ag & Resource Econ & Pol
# 3  1983-84              Male          1  Ag & Resource Econ & Pol
# 4  1983-84  Decline to State          8              Anthropology
#
#                        major
# 0   Afr Amer Stds-Humanities
# 1   Afr Amer Stds-Social Sci
# 2  Pol Econ of Nat Resources
# 3  Pol Econ of Nat Resources
# 4               Anthropology

# %%
# Filter to most recent year
df2 = df[df['year'] == '2015-16']
# Calculate department aggregates
agg = df2.groupby(['dept', 'gender']).sum().div(df2.groupby(['dept']).sum())
agg.head()
# Out:
#                                  headcount
# dept                     gender
# African American Studies Female   0.500000
#                          Male     0.500000
# Ag & Resource Econ & Pol Female   0.554745
#                          Male     0.445255
# Anthropology             Female   0.732143

# %%
agg.sort_values('headcount', ascending=False)
# Out:
#                                        headcount
# dept                           gender
# Other Env Design Programs      Female   1.000000
# Scandinavian                   Female   1.000000
# Near Eastern Studies           Female   0.928571
# Gender & Womens Studies        Female   0.900000
# Electrical Eng & Computer Sci  Male     0.887671
# Nuclear Engineering            Male     0.875000
# L&S Envir Econ & Policy        Male     0.857143
# History of Art                 Female   0.842105
# L&S Social Welfare             Female   0.839695
# Mechanical Engineering         Male     0.837838
# Physics                        Male     0.800000
# Spanish & Portuguese           Female   0.794872
# Chem & Biomolecular Eng        Male     0.786885
# Comparative Literature         Female   0.777778
# L&S Public Health              Female   0.770751
# Psychology                     Female   0.770588
# Art Practice                   Female   0.761905
# Italian Studies                Female   0.750000
# Slavic Languages & Literatures Female   0.750000
# Astronomy                      Male     0.735294
# Anthropology                   Female   0.732143
# Env Sci, Policy, & Mgmt        Female   0.728302
# L&S Computer Science           Male     0.715640
# Nutritional Sciences & Tox     Female   0.714286
# Sociology                      Female   0.714286
# Integrative Biology            Female   0.701754
# City & Regional Planning       Female   0.697674
# Mathematics                    Male     0.683019
# French                         Female   0.666667
# Theater Dance & Perf Stds      Female   0.666667
# ...                                          ...
# UG Interdisciplinary Studies   Male     0.339207
# English                        Male     0.338182
# Theater Dance & Perf Stds      Male     0.333333
# French                         Male     0.333333
# Mathematics                    Female   0.316981
# City & Regional Planning       Male     0.302326
# Integrative Biology            Male     0.298246
# Nutritional Sciences & Tox     Male     0.285714
# Sociology                      Male     0.285714
# L&S Computer Science           Female   0.284360
# Env Sci, Policy, & Mgmt        Male     0.271698
# Anthropology                   Male     0.267857
# Astronomy                      Female   0.264706
# Italian Studies                Male     0.250000
# Slavic Languages & Literatures Male     0.250000
# Art Practice                   Male     0.238095
# Psychology                     Male     0.229412
# L&S Public Health              Male     0.229249
# Comparative Literature         Male     0.222222
# Chem & Biomolecular Eng        Female   0.213115
# Spanish & Portuguese           Male     0.205128
# Physics                        Female   0.200000
# Mechanical Engineering         Female   0.162162
# L&S Social Welfare             Male     0.160305
# History of Art                 Male     0.157895
# L&S Envir Econ & Policy        Female   0.142857
# Nuclear Engineering            Female   0.125000
# Electrical Eng & Computer Sci  Female   0.112329
# Gender & Womens Studies        Male     0.100000
# Near Eastern Studies           Male     0.071429
#
# [130 rows x 1 columns]

# %%
agg.loc['Electrical Eng & Computer Sci']
# Out:
#         headcount
# gender
# Female   0.112329
# Male     0.887671

# %% [markdown]
# In the 2015-16 academic year, 89% of degrees awarded by the EECS department went to male students. That's the highest proportion of male graduates of any department.

# %%
agg.loc['L&S Computer Science']
# Out:
#         headcount
# gender
# Female    0.28436
# Male      0.71564

# %% [markdown]
# In the 2015-16 academic year, 72% of degrees awarded by the L&S CS department went to male students.

# %%
df3 = df2[df2['dept'].str.contains('Computer')]
agg3 = df3.groupby(['gender']).sum()
agg3
# Out:
#         headcount
# gender
# Female        161
# Male          626

# %%
df3.sum(0).headcount
# Out:
# 787

# %%
agg3.loc['Male'].headcount/df3.sum(0).headcount
# Out:
# 0.795425667090216

# %% [markdown]
# In total, 80% of the 787 degrees awarded in computer science (EECS and L&S CS) in the 2015-16 academic year went to males.

# %%
# Back to considering all years
# Filter to EECS & CS
df4 = df[df['dept'].str.contains('Computer')]
# Get rid of 1983-84, since it contains an unsually high number of students declining to state their gender
df4 = df4[df4['year'] != '1983-84']
#agg4 = df4[df4['gender'] == 'Male'].groupby(['year']).sum().div(df4.groupby(['year']).sum())
agg4 = df4.groupby(['year','gender']).sum().div(df4.groupby(['year']).sum())
# Save to CSV
agg4.to_csv('site/csv/cs_by_year.csv')

# %% [markdown]
# The proportion of male EECS and L&S CS graduates rose throughout the 2000s, peaked in 2010-11 at 90%, and has declined to 80% since then.

# %%
# Generate the data for the graphic
# Get rid of 1983-84, since it contains an unsually high number of students declining to state their gender
df5 = df[df['year'] != '1983-84']
# Calculate the number of female graduates by year and department
agg5 = df5[df5['gender'] == 'Female'].groupby(['year','dept']).sum()
agg5.columns = ['female_count']
agg5
# Calculate the number of graduates by year and department
agg6 = df5.groupby(['year','dept']).sum()
agg6.columns = ['total_count']
agg6
# Divide to get the proportion of female graduates
agg7 = pd.concat([agg5, agg6], axis=1)
agg7['female_pct'] = agg7['female_count'].div(agg7['total_count'])
# Exclude departments with fewer than 20 graduates
agg7 = agg7[agg7['total_count'] > 20]
# Save to CSV
agg7.to_csv('site/csv/data.csv')

# %%
# Generate the data for the graphic
# Get rid of 1983-84, since it contains an unsually high number of students declining to state their gender
df5 = df[df['year'] != '1983-84']
df5 = df5[df5['dept'].str.contains('Electrical')]
# Calculate the number of female graduates by year and department
agg5 = df5[df5['gender'] == 'Female'].groupby(['year','dept']).sum()
agg5.columns = ['female_count']
agg5
# Calculate the number of graduates by year and department
agg6 = df5.groupby(['year','dept']).sum()
agg6.columns = ['total_count']
agg6
# Divide to get the proportion of female graduates
agg7 = pd.concat([agg5, agg6], axis=1)
agg7['female_pct'] = agg7['female_count'].div(agg7['total_count'])
# Save to CSV
agg7
# Out:
#                                        female_count  total_count  female_pct
# year    dept
# 1984-85 Electrical Eng & Computer Sci            37          189    0.195767
# 1985-86 Electrical Eng & Computer Sci            36          233    0.154506
# 1986-87 Electrical Eng & Computer Sci            49          237    0.206751
# 1987-88 Electrical Eng & Computer Sci            44          216    0.203704
# 1988-89 Electrical Eng & Computer Sci            26          165    0.157576
# 1989-90 Electrical Eng & Computer Sci            34          231    0.147186
# 1990-91 Electrical Eng & Computer Sci            33          203    0.162562
# 1991-92 Electrical Eng & Computer Sci            28          209    0.133971
# 1992-93 Electrical Eng & Computer Sci            36          250    0.144000
# 1993-94 Electrical Eng & Computer Sci            25          233    0.107296
# 1994-95 Electrical Eng & Computer Sci            40          255    0.156863
# 1995-96 Electrical Eng & Computer Sci            34          242    0.140496
# 1996-97 Electrical Eng & Computer Sci            35          245    0.142857
# 1997-98 Electrical Eng & Computer Sci            34          239    0.142259
# 1998-99 Electrical Eng & Computer Sci            41          277    0.148014
# 1999-00 Electrical Eng & Computer Sci            56          306    0.183007
# 2000-01 Electrical Eng & Computer Sci            58          320    0.181250
# 2001-02 Electrical Eng & Computer Sci            55          341    0.161290
# 2002-03 Electrical Eng & Computer Sci            45          312    0.144231
# 2003-04 Electrical Eng & Computer Sci            67          329    0.203647
# 2004-05 Electrical Eng & Computer Sci            51          261    0.195402
# 2005-06 Electrical Eng & Computer Sci            52          330    0.157576
# 2006-07 Electrical Eng & Computer Sci            38          260    0.146154
# 2007-08 Electrical Eng & Computer Sci            21          224    0.093750
# 2008-09 Electrical Eng & Computer Sci            25          267    0.093633
# 2009-10 Electrical Eng & Computer Sci            25          268    0.093284
# 2010-11 Electrical Eng & Computer Sci            21          260    0.080769
# 2011-12 Electrical Eng & Computer Sci            35          311    0.112540
# 2012-13 Electrical Eng & Computer Sci            39          330    0.118182
# 2013-14 Electrical Eng & Computer Sci            42          407    0.103194
# 2014-15 Electrical Eng & Computer Sci            51          367    0.138965
# 2015-16 Electrical Eng & Computer Sci            41          365    0.112329
